# %%
import matplotlib.pyplot as plt
import math

# %%
f1 = open('timesInsertInMap.txt', 'r')
data1 = []
for line in f1:
    data1.append([int(x) for x in line.split()])
f1.close()

f2 = open('timesInsertInAVLTree.txt', 'r')
data2 = []
for line in f2:
    data2.append([int(x) for x in line.split()])
f2.close()

f3 = open('timesInsertInSplayTree.txt', 'r')
data3 = []
for line in f3:
    data3.append([int(x) for x in line.split()])
f3.close()

f4 = open('timesInsertInTreapTree.txt', 'r')
data4 = []
for line in f4:
    data4.append([int(x) for x in line.split()])
f4.close()

_, ax = plt.subplots()

xMap = []
yMap = []
xAVL = []
yAVL = []
xSplay = []
ySplay = []
xTreap = []
yTreap = []
for elem in data1:
    xMap.append(elem[0])
    yMap.append(elem[1])
for elem in data2:
    xAVL.append(elem[0])
    yAVL.append(elem[1])
for elem in data3:
    xSplay.append(elem[0])
    ySplay.append(elem[1])
for elem in data4:
    xTreap.append(elem[0])
    yTreap.append(elem[1])
ax.plot(xMap, yMap, lw = 0.5, color = "r", alpha = 1.0)
ax.plot(xAVL, yAVL, lw = 0.5, color = "b", alpha = 1.0)
ax.plot(xSplay, ySplay, lw = 0.5, color = "g", alpha = 1.0)
ax.plot(xTreap, yTreap, lw = 0.5, color = "k", alpha = 1.0)
pass

# %%
f1 = open('timesFindInMap.txt', 'r')
data1 = []
for line in f1:
    data1.append([int(x) for x in line.split()])
f1.close()

f2 = open('timesFindInAVLTree.txt', 'r')
data2 = []
for line in f2:
    data2.append([int(x) for x in line.split()])
f2.close()

f3 = open('timesFindInSplayTree.txt', 'r')
data3 = []
for line in f3:
    data3.append([int(x) for x in line.split()])
f3.close()

f4 = open('timesFindInTreapTree.txt', 'r')
data4 = []
for line in f4:
    data4.append([int(x) for x in line.split()])
f4.close()

_, ax = plt.subplots()

xMap = []
yMap = []
xAVL = []
yAVL = []
xSplay = []
ySplay = []
xTreap = []
yTreap = []
for elem in data1:
    xMap.append(elem[0])
    yMap.append(elem[1])
for elem in data2:
    xAVL.append(elem[0])
    yAVL.append(elem[1])
for elem in data3:
    xSplay.append(elem[0])
    ySplay.append(elem[1])
for elem in data4:
    xTreap.append(elem[0])
    yTreap.append(elem[1])
ax.plot(xMap, yMap, lw = 0.5, color = "r", alpha = 1.0)
ax.plot(xAVL, yAVL, lw = 0.5, color = "b", alpha = 1.0)
ax.plot(xSplay, ySplay, lw = 0.5, color = "g", alpha = 1.0)
ax.plot(xTreap, yTreap, lw = 0.5, color = "k", alpha = 1.0)
pass

# %%
f1 = open('timesRemoveInMap.txt', 'r')
data1 = []
for line in f1:
    data1.append([int(x) for x in line.split()])
f1.close()

f2 = open('timesRemoveInAVLTree.txt', 'r')
data2 = []
for line in f2:
    data2.append([int(x) for x in line.split()])
f2.close()

f3 = open('timesRemoveInSplayTree.txt', 'r')
data3 = []
for line in f3:
    data3.append([int(x) for x in line.split()])
f3.close()

f4 = open('timesRemoveInTreapTree.txt', 'r')
data4 = []
for line in f4:
    data4.append([int(x) for x in line.split()])
f4.close()

_, ax = plt.subplots()

xMap = []
yMap = []
xAVL = []
yAVL = []
xSplay = []
ySplay = []
xTreap = []
yTreap = []
for elem in data1:
    xMap.append(elem[0])
    yMap.append(elem[1])
for elem in data2:
    xAVL.append(elem[0])
    yAVL.append(elem[1])
for elem in data3:
    xSplay.append(elem[0])
    ySplay.append(elem[1])
for elem in data4:
    xTreap.append(elem[0])
    yTreap.append(elem[1])
ax.plot(xMap, yMap, lw = 0.5, color = "r", alpha = 1.0)
ax.plot(xAVL, yAVL, lw = 0.5, color = "b", alpha = 1.0)
ax.plot(xSplay, ySplay, lw = 0.5, color = "g", alpha = 1.0)
ax.plot(xTreap, yTreap, lw = 0.5, color = "k", alpha = 1.0)
pass
